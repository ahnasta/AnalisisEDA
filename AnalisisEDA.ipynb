# %% [markdown]
# <a href="https://colab.research.google.com/github/ahnasta/AnalisisEDA/blob/main/AnalisisEDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Latihan 1 — Operasi Dasar NumPy Array**

# %%
import numpy as np

harga = np.array([5000, 7000, 3000, 12000, 4500])

print('Rata-rata harga:', harga.mean())
print('Harga tertinggi:', harga.max())
print('Harga setelah diskon 10%:', harga * 0.9)
# Out:
# Rata-rata harga: 6300.0
# Harga tertinggi: 12000
# Harga setelah diskon 10%: [ 4500.  6300.  2700. 10800.  4050.]

# %% [markdown]
# List Python biasa tidak bisa dikalikan langsung dengan 0.9 dan akan menghasilkan error. NumPy Array dapat melakukan operasi tersebut langsung pada setiap elemen.

# %% [markdown]
# **Latihan 2 — Series & DataFrame**

# %%
import pandas as pd

data_kantin = {
    'menu': ['Nasi Goreng', 'Es Teh', 'Mie Ayam', 'Es Teh', None],
    'harga': [12000, 4000, 10000, 4000, 8000],
    'terjual': [23, 40, None, 35, 18]
}

df = pd.DataFrame(data_kantin)

print(df)
# Out:
#           menu  harga  terjual
# 0  Nasi Goreng  12000     23.0
# 1       Es Teh   4000     40.0
# 2     Mie Ayam  10000      NaN
# 3       Es Teh   4000     35.0
# 4         None   8000     18.0

# %% [markdown]
# Kolom menu dan terjual memiliki data kosong. Jika tidak dibersihkan, data kosong dapat membuat hasil analisis menjadi kurang tepat.

# %% [markdown]
# **Latihan 3 — Data Loading & Inspection**

# %%
df = pd.read_csv('data_kantin.csv')

print(df.head())
print(df.info())
print(df.describe())
print(df.shape)
# Out:
#       tanggal         menu kategori  harga  terjual
# 0  2026-08-20   Teh Hangat  Minuman   3000     11.0
# 1  2026-08-31  Nasi Goreng  Makanan  12000     29.0
# 2  2026-08-21  Nasi Goreng  Makanan  12000     28.0
# 3  2026-08-28   Teh Hangat  Minuman   3000     12.0
# 4  2026-08-21     Es Jeruk  Minuman   5000     19.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   110 non-null    object
#  1   menu      107 non-null    object
#  2   kategori  110 non-null    object
#  3   harga     110 non-null    int64
#  4   terjual   104 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 4.4+ KB
# None
#               harga     terjual
# count    110.000000  104.000000
# mean    6336.363636   22.923077
# std     3520.001232   10.831178
# min     2000.000000    8.000000
# 25%     3000.000000   13.000000
# ...

# %% [markdown]
# Kolom menu dan terjual memiliki jumlah non-null lebih sedikit dari total baris. Artinya, terdapat missing value pada kedua kolom tersebut.

# %% [markdown]
# **Latihan 4 — Menangani Missing Value**

# %%
print(df.isnull().sum())

df['terjual'] = df['terjual'].fillna(0)
df = df.dropna(subset=['menu'])

print(df)
# Out:
# tanggal     0
# menu        3
# kategori    0
# harga       0
# terjual     6
# dtype: int64
#         tanggal         menu kategori  harga  terjual
# 0    2026-08-20   Teh Hangat  Minuman   3000     11.0
# 1    2026-08-31  Nasi Goreng  Makanan  12000     29.0
# 2    2026-08-21  Nasi Goreng  Makanan  12000     28.0
# 3    2026-08-28   Teh Hangat  Minuman   3000     12.0
# 4    2026-08-21     Es Jeruk  Minuman   5000     19.0
# ..          ...          ...      ...    ...      ...
# 105  2026-09-01     Es Jeruk  Minuman   5000     24.0
# 106  2026-09-04  Nasi Goreng  Makanan  12000     28.0
# 107  2026-08-19      Kerupuk    Snack   2000     37.0
# 108  2026-08-25       Es Teh  Minuman   4000     44.0
# 109  2026-09-02      Kerupuk    Snack   2000     34.0
#
# [107 rows x 5 columns]

# %% [markdown]
# terjual diisi 0 agar data tetap dapat digunakan dalam perhitungan. Baris dengan menu kosong dihapus karena nama menu diperlukan untuk mengidentifikasi data.

# %% [markdown]
# **Latihan 5 — Duplikat & Tipe Data**

# %%
print(df.duplicated().sum())

df = df.drop_duplicates()

df['harga'] = df['harga'].astype(int)

print(df.dtypes)
# Out:
# 5
# tanggal      object
# menu         object
# kategori     object
# harga         int64
# terjual     float64
# dtype: object

# %% [markdown]
# Terdapat 5 data duplikat, sehingga setelah dihapus jumlah data menjadi 102 baris. Tipe data perlu sesuai agar setiap kolom dapat digunakan dengan benar, terutama untuk perhitungan numerik

# %% [markdown]
# **Latihan 6 — Data Manipulation**

# %%
laris = df[df['terjual'] > 20]

urut = df.sort_values(by='terjual', ascending=False)

df['total_pendapatan'] = df['harga'] * df['terjual']

ringkasan = df.groupby('menu')['total_pendapatan'].sum()

print(ringkasan)
# Out:
# menu
# Es Jeruk       1460000.0
# Es Teh         2144000.0
# Kerupuk         972000.0
# Mie Ayam       2410000.0
# Nasi Goreng    3924000.0
# Roti Bakar     1288000.0
# Teh Hangat      459000.0
# Name: total_pendapatan, dtype: float64

# %% [markdown]
# Nasi Goreng menghasilkan total pendapatan tertinggi, yaitu Rp3.924.000. Informasi ini dapat membantu kantin dalam mengatur stok dan penjualan menu.

# %% [markdown]
# Nama Anggota :
# 1.   Anastasya Putri Aulia
# 2.   Nazwa Putri Restyahartanti
#
# Dataset yang Dipilih :
# ☑ Data Penjualan Kantin/Toko
#
# Pertanyaan Analisis Awal
# 1.   Menu apa yang paling banyak terjual?
# 2.   Menu apa yang menghasilkan total pendatan tertinggi?
# 3. Bagaimana kondisi data penjualan setelah dilakukan cleaning?
#
# Dugaan Masalah Kualitas Data
# ☑ Missing value pada kolom: menu dan terjual
# ☑ Duplikat data
# ☑ Tipe data tidak sesuai pada kolom: harga
#
# Rencana Teknik Pembersihan :
# Mengisi missing value terjual dengan 0.
# Menghapus baris dengan menu yang kosong.
# Menghapus data duplikat.
# Memastikan harga menggunakan tipe data integer.
#
# Rencana Manipulasi Data :
# Filter: terjual > 20
# Sort: berdasarkan terjual dari terbesar ke terkecil
# Kolom turunan: total_pendapatan = harga × terjual
# Groupby/agregasi: total pendapatan berdasarkan menu
#
# Jadwal Kerja
# P3 – Loading & Inspection: Memuat dan mengecek kondisi data.
# P4 – Cleaning: Membersihkan missing value, duplikat, dan tipe data.
# P5 – Manipulation: Filter, sort, kolom turunan, dan groupby.
# P6 – Uji & Presentasi: Mengecek hasil, menyimpulkan, dan presentasi.
#
# Pembagian Peran :
# Anggota 1: Data Loading, Inspection, dan Cleaning
# Anggota 2: Data Manipulation, analisis hasil

# %% [markdown]
# **Proyek Akhir — EDA Starter Project**

# %%
import pandas as pd

# Data Loading
df = pd.read_csv('data_kantin.csv')

# Data Inspection
print("=== HEAD ===")
print(df.head())

print("\n=== INFO ===")
print(df.info())

print("\n=== DESCRIBE ===")
print(df.describe())

print("\n=== SHAPE ===")
print(df.shape)

# Data Cleaning
print("\n=== MISSING VALUE ===")
print(df.isnull().sum())

df['terjual'] = df['terjual'].fillna(0)
df = df.dropna(subset=['menu'])
df = df.drop_duplicates()
df['harga'] = df['harga'].astype(int)

print("\nJumlah data setelah cleaning:", df.shape)

# Filtering
laris = df[df['terjual'] > 20]

# Sorting
urut = df.sort_values(by='terjual', ascending=False)

# Kolom turunan
df['total_pendapatan'] = df['harga'] * df['terjual']

# Groupby
ringkasan = df.groupby('menu')['total_pendapatan'].sum()
ringkasan = ringkasan.sort_values(ascending=False)

# Output
print("\n=== MENU LARIS ===")
print(laris)

print("\n=== PENJUALAN TERTINGGI ===")
print(urut.head())

print("\n=== TOTAL PENDAPATAN PER MENU ===")
print(ringkasan)
# Out:
# === HEAD ===
#       tanggal         menu kategori  harga  terjual
# 0  2026-08-20   Teh Hangat  Minuman   3000     11.0
# 1  2026-08-31  Nasi Goreng  Makanan  12000     29.0
# 2  2026-08-21  Nasi Goreng  Makanan  12000     28.0
# 3  2026-08-28   Teh Hangat  Minuman   3000     12.0
# 4  2026-08-21     Es Jeruk  Minuman   5000     19.0
#
# === INFO ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   110 non-null    object
#  1   menu      107 non-null    object
#  2   kategori  110 non-null    object
#  3   harga     110 non-null    int64
#  4   terjual   104 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 4.4+ KB
# None
#
# === DESCRIBE ===
#               harga     terjual
# count    110.000000  104.000000
# mean    6336.363636   22.923077
# std     3520.001232   10.831178
# ...

# %% [markdown]
# Refleksi Proyek

# %% [markdown]
# ### 1. Tahap yang paling menantang
#
# Tahap yang paling menantang adalah **data cleaning**, karena harus menentukan cara menangani missing value dan data duplikat agar hasil analisis tetap sesuai.
#
# ### 2. Mengapa keputusan cleaning perlu memiliki alasan?
#
# Karena setiap data memiliki kondisi yang berbeda. Keputusan seperti mengisi atau menghapus data harus disesuaikan agar tidak memengaruhi hasil analisis secara tidak tepat.
#
# ### 3. Hubungan dengan pekerjaan Data Analyst
#
# Proyek ini mirip dengan pekerjaan Data Analyst karena data perlu **dicek, dibersihkan, diolah, lalu dianalisis** sebelum digunakan untuk mengambil kesimpulan.
